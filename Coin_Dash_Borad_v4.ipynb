# %%
import dash
import pandas as pd
import plotly.express as px
from dash import html
from dash import dcc
from dash.dependencies import Input, Output

# %%
df = pd.read_csv('cc_data.csv')
df[:10]
#d = ['2021-12-08','2021-12-07','2021-12-06']
#dft = df[df['Date'].isin(d)]
l = [0,1,3,4]
dfM = df.iloc[:,l]
dfM = pd.melt(dfM, id_vars=['Date','Date_Time'],var_name='hash', value_name='rate')
dfM
# Out:
#             Date        Date_Time             hash  rate
# 0              0                0    Reported_Hash     0
# 1     2021-11-21  13:33:51.397040    Reported_Hash    30
# 2     2021-11-21  13:34:53.458088    Reported_Hash    30
# 3     2021-11-21  14:01:40.669087    Reported_Hash    30
# 4     2021-11-21  14:03:51.583825    Reported_Hash    30
# ...          ...              ...              ...   ...
# 2117  2021-12-24  14:40:47.426735  Calculated_Hash    48
# 2118  2021-12-24  14:55:57.794487  Calculated_Hash    39
# 2119  2021-12-24  15:11:08.197005  Calculated_Hash    29
# 2120  2021-12-24  15:26:19.237384  Calculated_Hash    44
# 2121  2021-12-24  15:41:29.787091  Calculated_Hash    48
#
# [2122 rows x 4 columns]

# %%
#Current_Hash=dfM['rate'][-1:]
#Current_Hash

#dfRH = dfM[(dfM['Date']==dfM['Date'].max()) & (dfM['hash']=='Reported_Hash')]
#rh = dfRH[dfRH['Date_Time']==dfRH['Date_Time'].max()]['rate']
#dfM[(dfM['Date_Time']==dfM['Date_Time'].max()) & (dfM['Date']==dfM['Date'].max())]
#dfM['Date_Time']==dfM['Date_Time'].max()

# %%
app = dash.Dash(__name__)

app.layout = html.Div([ #main div
    html.Div(children=[ #graph Div
    dcc.Graph(id='graph-with-drop'),
    dcc.Dropdown(
        id='drop-year',
        options=[{'label':i,'value':i} for i in dfM['Date'].unique()],value=dfM['Date'].max()
    ), 
        html.Br(),
        ]), #CLOSE GRAPH Div
    
    html.Div(children=[ #reported hash div
        html.H1('Current Hash Rate'),
        dcc.Graph(id='reported_hash_pie')
    ],style={'padding': 10, 'flex': 1, 'display': 'inline-block', 'margin-left':'75px'}), #CLOSE REPORTED HASH div
    
    html.Div(children=[ #calc hash div
        html.H1('Calculated Hash Rate'),
        dcc.Graph(id='calc_hash_pie')
    ],style={'padding': 10, 'flex': 1, 'display': 'inline-block', 'margin-left':'275px'}) #CLOSE CALC HASH div
    
]) #close main div

@app.callback(
    Output('graph-with-drop', 'figure'),
    Input('drop-year', 'value'))
def update_figure(selected_year):
    filtered_df = dfM[dfM.Date == selected_year]
    fig = px.bar(filtered_df, x="Date_Time", y="rate",
                    color="hash", barmode='group')
    fig.update_layout(transition_duration=500)
    return fig

@app.callback(
    Output('reported_hash_pie', 'figure'),
    Input('drop-year', 'value'))
def update_figure(selected_year):
    dfRH = dfM[(dfM['Date']==dfM['Date'].max()) & (dfM['hash']=='Reported_Hash')]
    rh = dfRH[dfRH['Date_Time']==dfRH['Date_Time'].max()]['rate']

    labels = pd.Series([int(rh),'..'])
    values = pd.Series([int(rh),100-int(rh)])

    f = {'Label':labels, 'Value':values}
    df = pd.DataFrame(f)

    fig = px.pie(df,values='Value',names='Label')
    fig.update_traces(textinfo='label', hole=.5, textfont_size=18)
    fig.update_layout(annotations=[dict(text='Current_Hash_Rate',showarrow=False, font_size=20)]) 

    return fig

@app.callback(
    Output('calc_hash_pie', 'figure'),
    Input('drop-year', 'value'))
def update_figure(selected_year):
    dfRH = dfM[(dfM['Date']==dfM['Date'].max()) & (dfM['hash']=='Calculated_Hash')]
    ch = dfRH[dfRH['Date_Time']==dfRH['Date_Time'].max()]['rate']

    labels = pd.Series([int(ch),'..'])
    values = pd.Series([int(ch),100-int(ch)])

    f = {'Label':labels, 'Value':values}
    df = pd.DataFrame(f)

    fig = px.pie(df,values='Value',names='Label')
    fig.update_traces(textinfo='label', hole=.5, textfont_size=18)
    fig.update_layout(annotations=[dict(text='Calculated_Hash_Rate',showarrow=False, font_size=20)]) 

    return fig


if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [24/Dec/2021 15:43:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:43:08] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:43:08] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:43:08] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [24/Dec/2021 15:43:08] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [24/Dec/2021 15:43:08] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [24/Dec/2021 15:43:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:43:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:43:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:44:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:44:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:44:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:45:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:45:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:45:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:45:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:45:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2021 15:45:10] "POST /_dash-update-component HTTP/1.1" 200 -
